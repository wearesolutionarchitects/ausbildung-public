# %% [markdown]
# # Lernfelder 6-9, Kapitel 3.3 bis zum Kompetenzcheck, Arbeitsbuch S.111, Aufgabe 2 und Aufgabe 3 bis S.114
#
# ## Aufgabe 2
#
# ### 2.1 Überprüfen des Wissens über objektorientierte Programmierkonzepte
#
# > Erläutern von Klassen und Objekte anhand eines Beispiels aus dem Projekt "La Mediterranea"
#
# * UML Klassendiagramm
#
# |Klasse|Cocktail|
# | --- | --- |
# |Attribute|+name string|
# ||+preis: float|
# ||+staerke: integer|
# ||+volumen: float|
# |Methoden|+ __init__ (name, preis,starke, volumen):|
# ||+ __str__: string|
# ||+ __gt__ (preis, staerke): other,bool|
#
# ---
#
# ### 2.2 Erläuterung des Unterschides zwischen public und private

# %% [markdown]
# #### public
#
# Auf öffentliche (public) Komponenten darf uneingeschränkt zugegriffen werden. Public wird in einem Klassendiagramm mit einem __+ (Plus)__ gekennzeichnet. Im Python Code erkennt man es daran, das dem Attribut/der Methode __KEIN__ Unterstrich vorangestellt ist:

# %%
class Public:
   def public_methode(self):
      return self.public_attribut

# %% [markdown]
# #### protected
#
# Auf geschützte (protected) Komponenten kann nur innerhalb der eigenen Klasse und aus Klassen, die von dieser Klasse abgeleitet wurden, zugegriffen werden. Protected wird in einem Klassendiagramm mit einer __# (Raute)__ gekennzeichnet. Im Python Code erkennt man es daran, das dem Attribut/der Methode EIN Unterstrich vorangestellt ist:

# %%
class Protected:
   def _protected_methode(self):
      return self._protected_attribut

# %% [markdown]
# #### private
#
# Ein Zugriff auf private Komponenten ist nur innerhalb der Klasse erlaubt. Private wird in einem Klassendiagramm mit einem - (Minus) gekennzeichnet. Im Python Code erkennt man es daran, das dem Attribut/der Methode __ZWEI__ Unterstriche vorangestellt sind:

# %%
class Private:
    def __private_Methode(self):
        return self.__private_attribut

# %% [markdown]
# ## 2.3 Erläuterung des Unterschiedes zwischen Einfach- und Mehrfachvererbung anhand einer Skizze
#
# ||Merkmal|
# |---|---|
# |Einfachvererbung|Bei der Einfachvererbung hat eine abgeleitete eine Basisklasse, von  der sie erbt|
# |Mehrfachvererbung|Bei  der Mehrfachvererbung hat eine abgeleitete Klasse *mindestens zwei*  Basisklassen, von denen sie erbt|
#
# > siehe auch Aufgabe 3.4 zur Vererbung
#
# ## 2.4 Erläuterung des Überladens am Beispiel und Erweiterung des Klassendiagramms um eine weitere Methode
#
# * UML Klassendiagramm
#
# ||Button|
# ||---|
# |Attribut|- with: int|
# ||- height: int|
# ||- colour: Color|
# ||-|
# ||+ Buttton ()|
# ||+ Button(int, int, Color)|
# ||+ paint ()|
#
# ---
#
# |RoundButton|
# |---|
# |-|
# |+ RoundButtton ()|
# |+ paint ()|
#
# > Eine eckige Schaltfläche wird durch Überladung in eine runde Schaltfläche umgewandelt
#
# ## Aufgabe 3
#
# ### 3.1 Anwendung des Wissens über objektorientierte Programmparadigmen
#
# > UML-Klassendiagramm
#
# ||Reiter|Film|Rechteck|
# |---|---|---|---|
# |Attribut|-name: string|-titel:string|-a: double|
# ||-geburtsdatum: string|-ercheinungsjahr: integer|- b: double|
# ||-gewicht: float||-länge: double|
# |Methode|+ aufsteigen: (void)|+ starten(): void|+berechneUmfang: (void)|
# ||+ reiten: (void)|+ anhalten: (void)||
# ||+ absteigen: (void)|+zurückspulen: (void)|+berechneFlächeninhalt: (void)|
#
# ### 3.2 Wählen Sie selbständig zwei Klassen und ordnen Sie diesen jeweils drei sinnvolle Eigenschaften und Methoden zu. Tragen Sie Ihr Ergebnis mit entsprechenden Zugriffsmodifiern in das Klassendiagramm ein
#
# > UML Klassendiagramm
#
# ||Cocktail|Speise|
# |---|---|---|
# |Attribut|-name: string|-name:string|
# ||-zutat: string|-zutat:string|
# ||-volumen: float|-preis:float|
# |Methode|+mischen: (void)|+Einkaufen: (void)|
# ||+shaken: (void)|+Gemüseschneiden: (void)|
# ||+abseihen: (void)|+Grillen: (void)|
#
# ### 3.3 Recherchieren Sie im Internet zu den Problemen, welche bei der Mehrfachvererbung auftreten können. Diskutieren sie im Projektteam die Ergbenisse
#
# 1. __Komplexität und Undurchsichtigkeit:__ Mehrfachvererbung kann das Design unnötig kompliziert und undurchsichtig machen.
# 2. __Das Diamond-Problem:__ Dieses Problem entsteht, wenn eine Klasse auf zwei verschiedenen Vererbungspfaden von derselben Basisklasse erbt. Wenn man die Vererbungsbeziehungen zwischen den Klassen als Diagramm zeichnet, ergibt sich die Form einer Raute (englisch: diamond), nach der das Problem benannt ist.
# 3. __Namenskonflikte:__ Bei Mehrfachvererbung können Namenskonflikte auftreten. Die Programmiersprache Eiffel bietet Konstrukte zur transparenten Auflösung dieser Namenskonflikte.
# 4. __Replikation von Membern:__ In C++ kann das Konzept der virtuellen Basisklasse verwendet werden, um eine Replikation der Member der Basisklasse in der abgeleiteten Klasse zu vermeiden.
#
# Wegen dieser Probleme unterstützen einige objektorientierte Programmiersprachen keine Mehrfachvererbung. Stattdessen bieten sie Alternativkonzepte an, wie zum Beispiel die Konstruktion von Zwillingsklassen oder die Verwendung von Interfaces
#
# ### 3.4. Finden Sie im Projektteam mindestens eine sinnvolle Eigenschaft und Methode pro Klasse, welche nur für die entsprechende Klasse und daraus abgeleitete Klasse gilt
#
# > UML-Klassendiagramm
#
# ||Uhr|
# |---|---|
# |Attribut|-zifferblatt: string|
# ||-mechanik: string|
# ||-element: string|
# |Methode|+zifferblatt_wechseln: (void)|
# ||+ticken: (void)|
# ||+strömen: (void)|
# ||+rieseln: (void)|
# ---
#
# ||Digitaluhr|Räderuhr|Elementaruhr|
# |---|---|---|---|
# |Attribut|-zifferblatt: string|-mechanik:string|-element: string|
# |Methode|+ wechseln: (void)|+ ?(): void|+rieseln: (void)|
# |||+ ?(): void|+strömen: (void)|
#
# ---
#
# |Smartwatch|Pendeluhr|Sanduhr|
# |---|---|---|
# |Attribut|||
# |Methode|||
#
#
# ## Fahrzeuge (Einfachvererbung)
#
# > UML-Klassendiagramm
#
# ||Fahrzeug|
# |---|---|
# |Attribut|-bezeichnung: string|
# ||-geschwindigkeit: integer|
# |Methode|-def __str__(self): (void)|
# ||-def __gt__(self, other):|
#
# ||PKW|
# |---|---|
# |Attribut|+insassen: integer|
# |Methode|+def __str__(self): (void)|
# ||+def einsteigen(self, anzahl):|
# ||+def aussteigen(self, anzahl):|
#
# ---
#
# ## Beach-Bar und Restaurant "La Mediterranea" (Einfachvererbung)
#
# > UML-Klassendiagramm
#
# ||Restaurant|
# |---|---|
# |attribute|-closing_days:string|
# ||-opening_days:string|
# |method|+reserve():(void)|
# ||+isopen():void|
#
# ||Bar|
# |---|---|
# |attribute|-name:string|
# |method|+reserve():(void)|
# ||+isopen():void|

# %%
# base class
class Restaurant:
    def __init__(self, name):
        self.name = name
    def is_open(self):
        print(f"{self.name} ist geöffnet.")

# extended class
class Beachbar(Restaurant):
    def __init__(self, name, amount_tables):
        super().__init__(name)
        self.amount_tables = amount_tables

    def reserve(self):
        print(f"Ein Tisch in {self.name} wurde reserviert.")

# %% [markdown]
# # Assoziation
#
# Die Assoziation gibt an, dass eine Verbindung zwischen den Objekten von zwei Klassen besteht.
# Beispiel: Eine Maschine erstellt oder bearbeitet ein Werkstück. Es besteht also eine Beziehung.
# Allerdings ist die Beziehung keine Teil-Ganzes-Beziehung
#
# ## unidirektional
#
# ------------>
# <------------
#
# ## bidirektionale
#
# <----------->

# %%
class Maschine():

    def __init__(self,nr): # Konstruktor
        self.nummer = nr
        self.werkstueck_id = 0
        #self.werkstueck_id_liste = [] # Speicherort = [], integer

    def herstellen(self,werkstueck):
        self.werkstueck_id = werkstueck.get_werkstueck_id() # Speichervorgang
        # dann werstueck_id in eine Liste packen

class Werkstueck():

    def __init__(self,nr): # Konstruktor
        self.werkstueck_id = nr
        #self.werkstueck_id_liste = []


    def get_werkstueck_id(self): # Lesemethode
        return self.werkstueck_id
m1 = Maschine(11)
m2 = Maschine(12)

w1 = Werkstueck(1)
w2 = Werkstueck(2)

# %% [markdown]
# # Aggregation
#
# Die Aggregation ist eine Variante der Assoziation. ln diesem Fall ist es eine Teil-Ganzes- Beziehung.
# Bei der Aggregation können die einzelnen Objekte aber auch unabhängig voneinander existieren. Die "Ganzes"-
# Klasse wird auch als Aggregationsklasse bezeichnet. Beispiel: Die Aggregationsklasse ist das Auto. Die Räder sind ein Bestandteil eines Autos, können aber auch abmontiert werden und unabhängigvom Auto existieren.

# %%
class Auto():

    def __init__(self):
        self.raeder = [] #Datentyp Rad

# %% [markdown]
# # Komposition
#
# > Feste Komponentenverbindung
#
# Die Komposition ist eine Variante der Aggregation. Die Komposition erfordert einen starken
# Besitz über die Teilobjekte. Der starke Besitz hat Auswirkungen auf den Umgang mit dem Aggregationsobjekt. Wird z. B. das Ganze gelöscht, werden dieTeile auch gelöscht. Das heißt, die Teile können nicht ohne das Ganze existieren. Beispiel: Das Ganze ist in diesem Fall das Haus und die Räume sind ein Bestandteil des Hauses. Wird das Haus abgerissen, existieren auch die Räume des Hauses nicht mehr.

# %%
class Haus():
    def __init__(self, raum_objekt):
        self.raeume = []  # Datentyp Raum
        # self.raeume = Raum()  # in din Liste Räume muss ein Opjekt vom Typ Raum eingestellt werden:
        # liste.append(Raum()), raum = Raum(), liste.append(raum)

class BarRestaurant():
    def __init__(self, area_objekt):
        self.areas = [] # Datentyp Area

class Area():
    def __init__(self, name):
        self.name = name # Datentyp String

# %% [markdown]
# # Entertainment / Unterhaltung
#
# | Klasse | Vererbung | Attribute |
# |--------|-----------|-----------|
# | Unterhaltung | - | - |
# | Speisen | Unterhaltung | Art der Speise, Zutaten, Zubereitungszeit |
# | Getränke | Unterhaltung | Art des Getränks, Zutaten, Zubereitungszeit |
# | Musik | Unterhaltung | Genre, Dauer, Künstler |

# %% [markdown]
# ## Erweiterte tabellarische Darstellung des UML-Klassendiagramms mit Methoden für jede Klasse
#
# | Klasse | Vererbung | Attribute | Beziehungen | Methoden |
# |--------|-----------|-----------|-------------|----------|
# | Unterhaltung | - | - | - | - |
# | Speisen | Unterhaltung | Art der Speise, Zutaten, Zubereitungszeit | Unterhaltung hat Speisen | zubereiten(), servieren() |
# | Getränke | Unterhaltung | Art des Getränks, Zutaten, Zubereitungszeit | Unterhaltung hat Getränke | mischen(), servieren() |
# | Musik | Unterhaltung | Genre, Dauer, Künstler | Unterhaltung hat Musik | spielen(), stoppen() |

# %% [markdown]
# ### Beispiel einer neuen Klasse namens “Spiele” , die von der Klasse “Unterhaltung” erbt:
#
# | Klasse | Vererbung | Attribute | Beziehungen | Methoden |
# |--------|-----------|-----------|-------------|----------|
# | Unterhaltung | - | - | - | - |
# | Speisen | Unterhaltung | Art der Speise, Zutaten, Zubereitungszeit | Unterhaltung hat Speisen | zubereiten(), servieren() |
# | Getränke | Unterhaltung | Art des Getränks, Zutaten, Zubereitungszeit | Unterhaltung hat Getränke | mischen(), servieren() |
# | Musik | Unterhaltung | Genre, Dauer, Künstler | Unterhaltung hat Musik | spielen(), stoppen() |
# | Spiele | Unterhaltung | Art des Spiels, Dauer, Anzahl der Spieler | Unterhaltung hat Spiele | starten(), beenden() |

# %%
class Speise:
    def __init__(self,  nummer, name,  preis, kategorie):
        self.nummer = nummer
        self.name = name
        self.preis = preis
        self.kategorie = kategorie

    def __str__(self):
        return f"Nummer: {self.nummer}, Gericht: {self.name},  Preis: {self.preis} €, Kategorie {self.kategorie}"


rinderfilet_rotweinsause = Speise(1, "Rinderfilet mit Rotweinsause", 35, "Fleisch")
haehnchen_curry = Speise(2, "Haehnchen-Curry mit Basmatireis", 28, "Fleisch")
beef_burger = Speise(3, "Beef Burger", 16, "Fleisch")
schweinefilet = Speise(4, "Schweinefilet mit Champignon-Rahmsauce", 26, "Fleisch")
lammkoteletts = Speise(5, "Lammkoteletts mit Rosmarin-Kartoffeln", 32, "Fleisch")
spaghetti_bolognese = Speise(6, "Spaghetti Bolognese", 14, "Fleisch")
rinderrouladen = Speise(7, "Rinderrouladen mit Rotkohl und Klößen", 34, "Fleisch")
haehnchensalat = Speise(8, "Hähnchensalat mit Avocado", 24, "Fleisch")
chili_con_carne = Speise(9, "Chili con Carne", 25, "Feisch")
pasta_carbonara = Speise(10, "Pasta Carbonara", 23, "Fleisch")

gebratener_lachs = Speise(11, "Gebratener Lachs mit Zitronen-Kräuter-Butter", 38, "Fisch")
garnelenspiesse = Speise(12, "Garnelenspieße mit Knoblauch und Zitrone", 32, "Fisch")
thunfischsteak = Speise(13, "Thunfischsteak mit Sesamkruste", 38, "Fisch")
calamari = Speise(14, "Calamari Fritti mit Aioli", 29, "Fisch")
forelle = Speise(15, "Forelle Müllerin Art", 33, "Fisch")
scampi = Speise(16, "Scampi in Knoblauchbutter", 28, "Fisch")
lachs_ceviche = Speise(17, "Lachs-Ceviche mit Avocado", 36, "Fisch")
muscheln = Speise(18, "Muscheln in Weißweinsauce", 30, "Fisch")
gebratene_jakobsmuscheln = Speise(19, "Gebratene Jakobsmuscheln mit Spargel", 28, "Fisch")
seeteufel = Speise(20, "Seeteufel mit Tomaten-Oliven-Salsa", 33, "Fisch")


print(rinderfilet_rotweinsause)
print(haehnchen_curry)
print(beef_burger)
print(schweinefilet)
print(schweinefilet)
print(spaghetti_bolognese)
print(rinderrouladen)
print(haehnchensalat)
print(chili_con_carne)
print(pasta_carbonara)

print(gebratener_lachs)
print(garnelenspiesse)
print(calamari)
print(forelle)
print(scampi)
print(lachs_ceviche)
print(muscheln)
print(gebratene_jakobsmuscheln)
print(seeteufel)

# %%
class Speise:

    def __init__(self,  nummer, name,  preis, kategorie,zutaten ):

        self.nummer    = nummer
        self.name      = name
        self.preis     = preis
        self.kategorie = kategorie
        self.zutaten  = zutaten



    def speise(self):

      zutaten_str = ', '.join(self.zutaten)
      return f"{self.nummer} Gericht: {self.name},  Preis: {self.preis} €, Kategorie: {self.kategorie} \n Zutaten: {zutaten_str}"


Schokoladen_Brownie = Speise(1, "Schokoladen-Brownie ", 28, "Süßspeisen" , ["Schokolade", "Butter", "Zucker","Eier", "Mehl", "Nüsse"])
Apfel_Crumble_mit_Vanillesauce= Speise(2, "Apfel-Crumble mit Vanillesauce", 23, "Süßspeisen",["Äpfel", "Haferflocken", "Butter", "Zucker", "Zimt", "Vanillesauce"])
Erdbeer_Tiramisu = Speise(3, "Erdbeer-Tiramisu ", 35, "Süßspeisen",["Erdbeeren", "Löffelbiskuits", "Mascarpone", "Zucker", "Kaffee", "Kakao"])
Zitronen_Mohn_Kuchen = Speise(4, "Zitronen-Mohn-Kuchen", 15, "Süßspeisen",["Zitrone", "Mohn", "Butter", "Zucker", "Mehl", "Eier"])
Beeren_Panna_Cotta = Speise(5, "Beeren-Panna Cotta ", 22, "Süßspeisen",["Beeren", "Sahne", "Gelatine", "Zucker", "Vanille"])
Bananen_Split = Speise(6, "Bananen-Split ", 10, "Süßspeisen",["Bananen", "Eis", "Sahne", "Schokoladensauce", "Nüsse"])
Kaiserschmarrn_mit_Apfelmus = Speise(7, "Kaiserschmarrn mit Apfelmus ", 31, "Süßspeisen",["Mehl", "Eier", "Milch", "Rosinen", "Puderzucker", "Apfelmus"])
Himbeer_Mousse = Speise(8, "Himbeer-Mousse ", 24, "Süßspeisen",["Himbeeren", "Sahne", "Zucker","Gelatine", "Zitrone"])
Crêpes_mit_Nutella_und_Banane = Speise(9, "Crêpes mit Nutella und Banane ", 32, "Süßspeisen",["Crêpes", "Nutella", "Bananen", "Schokoladensauce"])
Vanillepudding_mit_Karamellsauce = Speise(10, "Vanillepudding mit Karamellsauce", 25, "Süßspeisen",["Milch", "Vanille", "Zucker", "Maisstärke", "Karamellsauce"])


print(Schokoladen_Brownie.speise())
print(Apfel_Crumble_mit_Vanillesauce.speise())
print(Erdbeer_Tiramisu.speise())
print(Zitronen_Mohn_Kuchen .speise())
print(Beeren_Panna_Cotta.speise())
print(Bananen_Split.speise())
print(Kaiserschmarrn_mit_Apfelmus.speise())
print(Himbeer_Mousse.speise())
print(Crêpes_mit_Nutella_und_Banane.speise())
print(Vanillepudding_mit_Karamellsauce.speise())
# Out:
# 1 Gericht: Schokoladen-Brownie ,  Preis: 28 €, Kategorie: Süßspeisen
#  Zutaten: Schokolade, Butter, Zucker, Eier, Mehl, Nüsse
# 2 Gericht: Apfel-Crumble mit Vanillesauce,  Preis: 23 €, Kategorie: Süßspeisen
#  Zutaten: Äpfel, Haferflocken, Butter, Zucker, Zimt, Vanillesauce
# 3 Gericht: Erdbeer-Tiramisu ,  Preis: 35 €, Kategorie: Süßspeisen
#  Zutaten: Erdbeeren, Löffelbiskuits, Mascarpone, Zucker, Kaffee, Kakao
# 4 Gericht: Zitronen-Mohn-Kuchen,  Preis: 15 €, Kategorie: Süßspeisen
#  Zutaten: Zitrone, Mohn, Butter, Zucker, Mehl, Eier
# 5 Gericht: Beeren-Panna Cotta ,  Preis: 22 €, Kategorie: Süßspeisen
#  Zutaten: Beeren, Sahne, Gelatine, Zucker, Vanille
# 6 Gericht: Bananen-Split ,  Preis: 10 €, Kategorie: Süßspeisen
#  Zutaten: Bananen, Eis, Sahne, Schokoladensauce, Nüsse
# 7 Gericht: Kaiserschmarrn mit Apfelmus ,  Preis: 31 €, Kategorie: Süßspeisen
#  Zutaten: Mehl, Eier, Milch, Rosinen, Puderzucker, Apfelmus
# 8 Gericht: Himbeer-Mousse ,  Preis: 24 €, Kategorie: Süßspeisen
# ...
